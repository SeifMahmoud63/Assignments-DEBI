# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.shape
# Out:
# (418, 12)

# %%
SumOfCabinNull=df['Cabin'].isnull().sum()

# %%
df['Cabin'].fillna("NO",inplace=True)
# Out:
# C:\Users\test\AppData\Local\Temp\ipykernel_2128\4049242439.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cabin'].fillna("NO",inplace=True)

# %%
sex_counts = df['Sex'].value_counts()  
plt.bar(sex_counts.index, sex_counts.values, color=['blue', 'black'])
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Number of Males and Females')
plt.show()

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
plt.hist(df.Age,bins=30)
plt.xticks([0,5,10,15,20,25,30,35,40,45,50,55,60,65,70,75])
# Between 25 to 30 high Age
# Out:
# ([<matplotlib.axis.XTick at 0x2420ef28200>,
# ...
#  [Text(0, 0, '0'),
#   Text(5, 0, '5'),
#   Text(10, 0, '10'),
#   Text(15, 0, '15'),
#   Text(20, 0, '20'),
#   Text(25, 0, '25'),
#   Text(30, 0, '30'),
#   Text(35, 0, '35'),
#   Text(40, 0, '40'),
#   Text(45, 0, '45'),
#   Text(50, 0, '50'),
#   Text(55, 0, '55'),
#   Text(60, 0, '60'),
#   Text(65, 0, '65'),
#   Text(70, 0, '70'),
#   Text(75, 0, '75')])

# %%
plt.scatter(df['Age'], df['Fare'], alpha=0.5, color='blue')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()
# we have outlier here

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.query("`Fare` > 500")
# this female is outlier for the model
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 343      1  PC 17755  512.3292  B51 B53 B55        C

# %%
df['Survived'].replace({1: 'Survived', 0: 'Not Survived'}, inplace=True)

# %%
df
# Out:
#      PassengerId      Survived  Pclass  \
# 0            892  Not Survived       3
# 1            893      Survived       3
# 2            894  Not Survived       2
# 3            895  Not Survived       3
# 4            896      Survived       3
# ..           ...           ...     ...
# 413         1305  Not Survived       3
# 414         1306      Survived       1
# 415         1307  Not Survived       3
# 416         1308  Not Survived       3
# 417         1309  Not Survived       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df['Survived'].value_counts()
# Out:
# Survived
# Not Survived    266
# Survived        152
# Name: count, dtype: int64

# %%
sur_counts = df['Survived'].value_counts()  
plt.bar(sur_counts.index, sur_counts.values, color=['blue', 'black'])
plt.xlabel('survived')
plt.ylabel('Count')
plt.title('Number of Survived or Not')
plt.legend()
plt.show()
# Out:
# C:\Users\test\AppData\Local\Temp\ipykernel_2128\893707345.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df['Survived'].replace({'Survived':1, 'Not Survived':0 }, inplace=True)
# Out:
# C:\Users\test\AppData\Local\Temp\ipykernel_2128\2322447248.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Survived'].replace({'Survived':1, 'Not Survived':0 }, inplace=True)

# %%
plt.hist(df[df['Survived'] == 1]['Age'], alpha=0.5, label='Survived', bins=20)
plt.hist(df[df['Survived'] == 0]['Age'], alpha=0.5, label='Not Survived', bins=20)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution by Survived Status')
plt.legend()
plt.show()
